# %%
import plotly
from synbacktest import *
import seaborn as sns

# %%
forcast = [-10] 
half_life = [25]
a = [] 
out = [] 
for p in product(forcast,half_life):
    out = syntheticBackTesting(p[0],p[1],1,nIteration =1e3)

# %%
sns.heatmap(out.T)
# Out:
# <AxesSubplot:>
